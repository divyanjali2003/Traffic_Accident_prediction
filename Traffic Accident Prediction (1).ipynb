# %%
import pandas as pd

# %%
df=pd.read_csv("kerala_accident_data_with_datetime.csv")

# %%
df
# Out:
#     Accident_ID            Date_Time   Latitude  Longitude  Severity  \
# 0       ACC0001  2023-11-13 07:50:04  11.925776  76.339349     Minor
# 1       ACC0002  2024-10-01 07:12:56  11.616621  76.953466    Severe
# 2       ACC0003  2023-07-02 09:49:19  10.458114  74.768419     Minor
# 3       ACC0004  2024-02-10 09:23:47  11.936447  74.886708  Moderate
# 4       ACC0005  2023-03-03 14:35:48  10.876408  75.207048  Moderate
# ..          ...                  ...        ...        ...       ...
# 995     ACC0996  2025-01-07 05:37:08   9.299732  75.727023     Minor
# 996     ACC0997  2024-09-21 07:58:08   8.853634  75.513562     Minor
# 997     ACC0998  2023-08-22 10:36:55  11.026919  76.266075     Minor
# 998     ACC0999  2023-12-25 00:49:06  11.467202  77.397851     Minor
# 999     ACC1000  2023-09-25 22:40:54  11.594171  75.131937     Minor
#
#     Weather_Condition Road_Type Vehicle_Type
# 0               Foggy     Urban          Car
# 1               Clear     Urban         Bike
# 2               Rainy     Rural          Car
# 3               Clear     Urban          Car
# 4               Rainy   Highway          Bus
# ..                ...       ...          ...
# 995             Clear   Highway          Car
# 996             Clear     Rural          Car
# 997             Rainy     Urban          Bus
# 998             Clear     Urban          Bus
# 999             Clear   Highway        Truck
#
# [1000 rows x 8 columns]

# %%
features=['Latitude','Longitude','Severity','Weather_Condition','Road_Type','Vehicle_Type']

# %%
df1=df[features]

# %%
df1
# Out:
#       Latitude  Longitude  Severity Weather_Condition Road_Type Vehicle_Type
# 0    11.925776  76.339349     Minor             Foggy     Urban          Car
# 1    11.616621  76.953466    Severe             Clear     Urban         Bike
# 2    10.458114  74.768419     Minor             Rainy     Rural          Car
# 3    11.936447  74.886708  Moderate             Clear     Urban          Car
# 4    10.876408  75.207048  Moderate             Rainy   Highway          Bus
# ..         ...        ...       ...               ...       ...          ...
# 995   9.299732  75.727023     Minor             Clear   Highway          Car
# 996   8.853634  75.513562     Minor             Clear     Rural          Car
# 997  11.026919  76.266075     Minor             Rainy     Urban          Bus
# 998  11.467202  77.397851     Minor             Clear     Urban          Bus
# 999  11.594171  75.131937     Minor             Clear   Highway        Truck
#
# [1000 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label1=LabelEncoder()
label2=LabelEncoder()
label3=LabelEncoder()
label4=LabelEncoder()

# %%
df1["Weather_Condition"]=label1.fit_transform(df["Weather_Condition"])
df1["Vehicle_Type"]=label2.fit_transform(df["Vehicle_Type"])
df1["Severity"]=label3.fit_transform(df["Severity"])
df1["Road_Type"]=label4.fit_transform(df["Road_Type"])
# Out:
# C:\Users\Diyanjali\AppData\Local\Temp\ipykernel_147868\2434485995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Weather_Condition"]=label1.fit_transform(df["Weather_Condition"])
# C:\Users\Diyanjali\AppData\Local\Temp\ipykernel_147868\2434485995.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Vehicle_Type"]=label2.fit_transform(df["Vehicle_Type"])
# C:\Users\Diyanjali\AppData\Local\Temp\ipykernel_147868\2434485995.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Severity"]=label3.fit_transform(df["Severity"])
# C:\Users\Diyanjali\AppData\Local\Temp\ipykernel_147868\2434485995.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Road_Type"]=label4.fit_transform(df["Road_Type"])

# %%
df1
# Out:
#       Latitude  Longitude  Severity  Weather_Condition  Road_Type  \
# 0    11.925776  76.339349         0                  1          2
# 1    11.616621  76.953466         2                  0          2
# 2    10.458114  74.768419         0                  2          1
# 3    11.936447  74.886708         1                  0          2
# 4    10.876408  75.207048         1                  2          0
# ..         ...        ...       ...                ...        ...
# 995   9.299732  75.727023         0                  0          0
# 996   8.853634  75.513562         0                  0          1
# 997  11.026919  76.266075         0                  2          2
# 998  11.467202  77.397851         0                  0          2
# 999  11.594171  75.131937         0                  0          0
#
#      Vehicle_Type
# 0               2
# 1               0
# 2               2
# 3               2
# 4               1
# ..            ...
# 995             2
# 996             2
# 997             1
# 998             1
# 999             3
#
# [1000 rows x 6 columns]

# %%
df1.isnull().sum()
# Out:
# Latitude             0
# Longitude            0
# Severity             0
# Weather_Condition    0
# Road_Type            0
# Vehicle_Type         0
# dtype: int64

# %%
x=df1[features]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 1.28212874,  0.41072421, -0.74355017,  0.49554175,  1.13241039,
#          0.61048771],
#        [ 1.0484829 ,  1.12532748,  2.22471398, -0.64889647,  1.13241039,
#         -1.3878354 ],
#        [ 0.17293391, -1.41725274, -0.74355017,  1.63997996,  0.01563486,
#          0.61048771],
#        ...,
#        [ 0.60281188,  0.32546059, -0.74355017,  1.63997996,  1.13241039,
#         -0.38867385],
#        [ 0.93555855,  1.64242598, -0.74355017, -0.64889647,  1.13241039,
#         -0.38867385],
#        [ 1.03151617, -0.99425329, -0.74355017, -0.64889647, -1.10114068,
#          1.60964927]])

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.plot(range(1,11),wcss,marker='o')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of clusters')
plt.ylabel('Intertia')
plt.show()

# %%
optimal_k = 6
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
df1['Cluster'] = kmeans.fit_predict(x_scaled)
# Out:
# C:\Users\Diyanjali\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\Diyanjali\AppData\Local\Temp\ipykernel_147868\3599632013.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Cluster'] = kmeans.fit_predict(x_scaled)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df1['Longitude'], df1['Latitude'], c=df1['Cluster'], cmap='viridis', s=5)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Traffic Accident Hotspots - {optimal_k} Clusters')
plt.colorbar(label='Cluster')
plt.show()

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_avg = silhouette_score(x_scaled, df1['Cluster'])
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.15422936643581783

# %%
import pickle
with open('kmeans_model.pkl', 'wb') as model_file:
    pickle.dump(kmeans, model_file)
with open('kmeans_scaler.pkl', 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)
if 'label_encoder' in locals():  
    with open('kmeans_label.pkl', 'wb') as label_file:
        pickle.dump(label_encoder, label_file)
print("Model, scaler, and label encoder (if used) saved successfully.")
# Out:
# Model, scaler, and label encoder (if used) saved successfully.

# %%
print(kmeans.cluster_centers_)
# Out:
# [[ 4.35356303e-01 -4.82603973e-01 -3.56728512e-01 -6.30634155e-01
#    2.77007855e-01 -1.00517778e+00]
#  [ 5.77371348e-02 -1.04728505e-01 -2.18674192e-01  1.59811027e+00
#   -1.16035702e-02  7.07966887e-01]
#  [-5.80018458e-02 -1.38365366e-01  1.10311799e+00 -4.47964567e-01
#    9.61910309e-01  5.95233336e-01]
#  [-9.66973255e-02  1.15981044e+00 -3.99933384e-01 -5.75607320e-01
#    1.14659289e-01  1.98503377e-02]
#  [-1.83472386e-01 -4.41854028e-01  1.89332849e-01 -5.99849115e-01
#   -9.15011420e-01  5.58150677e-01]
#  [-2.45758414e-01 -1.59820077e-01 -1.48413208e-03  1.51893361e+00
#   -7.02709528e-02 -1.21490359e+00]]
